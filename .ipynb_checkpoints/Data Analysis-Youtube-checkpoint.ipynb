# %%
import pandas as pd
import os
df = pd.read_excel("E:\CDAC\subjects\DATA Visualization\Pathak sir example\SuperStoreUS-2015.xlsx")
df.head()
# print(df)
# files = [file for file in os.listdir('E:\CDAC\subjects\DATA Visualization\Pathak sir example')]

# for file in files:
#     print(file)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
#cleaning data

df.head(50)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    20847           High      0.01        2.84           0.93            3
# 1    20228  Not Specified      0.02      500.98          26.00            5
# 2    21776       Critical      0.06        9.48           7.29           11
# 3    24844         Medium      0.09       78.69          19.99           14
# 4    24846         Medium      0.08        3.28           2.31           14
# 5    24847         Medium      0.05        3.28           4.20           14
# 6    24848         Medium      0.05        3.58           1.63           14
# 7    18181       Critical      0.00        4.42           4.99           15
# 8    20925         Medium      0.01       35.94           6.66           15
# 9    26267           High      0.04        2.98           1.58           16
# 10   26268           High      0.05      115.99           2.50           16
# ...

# %%
#removing NaN values
nan_df = df[df.isna().any(axis=1)]
nan_df.head()

# to drop NaN values
# df = df.dropna(how='all')

# city = df[df['City']=='Medford']
# city
# Out:
#      Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 181   18261       Critical      0.06      276.20          24.49          335
# 271   18305       Critical      0.01      128.24          12.65          508
# 483   24764       Critical      0.09      349.45          60.00          868
# 660   19185           High      0.09      349.45          60.00         1178
# 700   20592         Medium      0.03      128.24          12.65         1237
#
#         Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 181  Curtis O'Connell     Regular Air        Corporate        Furniture  ...
# 271     Cameron Owens     Regular Air        Corporate        Furniture  ...
# 483      Sharon Ellis  Delivery Truck        Corporate        Furniture  ...
# 660        Sandy Hunt  Delivery Truck         Consumer        Furniture  ...
# 700       Eva Simpson     Regular Air        Corporate        Furniture  ...
#
# ...

# %%
df['Month'] = df['Order Date'].astype('str')  #creating new column--astype()-to convert int to string
df['Month'] = df['Month'].str[5:7]
# df['Month'] = df['Order Date'].astype('int')
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
results = df.groupby('Month').sum()
print(results.head())
# Out:
#         Row ID  Discount  Unit Price  Shipping Cost  Customer ID  \
# Month
# 01     7400422     17.11    50813.88        4816.05       629315
# 02     6214875     15.12    33864.36        4665.55       566660
# 03     6683372     16.57    43341.13        4083.38       575229
# 04     6256923     15.63    38273.12        4317.23       552627
# 05     6331654     15.77    17812.67        3439.34       524560
#
#        Product Base Margin  Postal Code        Profit  Quantity ordered new  \
# Month
# 01                  187.44     18970019   1043.677500                  3368
# 02                  161.88     17242422  35944.658780                  4220
# 03                  169.73     17495008    103.159587                  3592
# 04                  162.77     15351266  53146.412502                  3955
# 05                  157.71     16853204  67002.732858                  5813
#
#            Sales  Order ID
# Month
# 01     274766.92  30479582
# 02     326101.47  25547481
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pylot as plt
months = range(1,6)

plt.bar(months,results['Profit'])    #months=x-axis,results=y-axis
plt.show()
plt.xticks(months)
plt.ylabel('anyname')
plt.xlabel('anyname')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 import matplotlib.pylot as plt
#       2 months = range(1,6)
#       4 plt.bar(months,results['Profit'])    #months=x-axis,results=y-axis
#
# ModuleNotFoundError: No module named 'matplotlib.pylot'
